# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanmaVL/SyS/blob/main/LABS_SyC_/LAB1/Simulacion_1_MODELADO_Y_ANALISIS_DE_SISTEMAS_DIN%C3%81MICOS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install control
# Funciones matemáticas
import numpy as np
# Funciones para graficos
import matplotlib.pyplot as plt
# Funciones parecidas a Matlab
from control.matlab import *
# Funciones para graficos
import matplotlib.pyplot as plt
# Funciones parecidas a Matlab
from control.matlab import *
# Funciones para graficos
import matplotlib.pyplot as plt
# Funciones parecidas a Matlab
from control.matlab import *
# Funciones para graficos
import matplotlib.pyplot as plt
# Funciones parecidas a Matlab
from control.matlab import *
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.6/549.6 kB 6.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## SISTEMAS DINAMICOS Y DE CONTROL 2025-1
# ##SIMULACIÓN 1: MODELADO Y ANALISIS DE SISTEMAS DINÁMICOS
#
# **Victor Manuel Villa**
#
# **Juan Manuel Valencia Lopez**

# %% [markdown]
# ## SISTEMA DE TANQUES

# %%
#definición del sistema de tanques
num=[0.3188]
den=[1., 1.143, 0.3188]
ftla= tf(num, den)
print('Funcion de transferencia en LA de la planta: ')
print(ftla)
ftlc=feedback(ftla,1)
print("Funcion de transferencia en lazo cerrado de la planta: ")
print(ftlc)
# Out:
# Funcion de transferencia en LA de la planta:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#         0.3188
# ----------------------
# s^2 + 1.143 s + 0.3188
#
# Funcion de transferencia en lazo cerrado de la planta:
# <TransferFunction>: sys[2]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#         0.3188
# ----------------------
# s^2 + 1.143 s + 0.6376

# %%
# Gráfico de polos y ceros del sistema en lazo cerrado.
plt.figure(1, figsize=[7, 4])
pzmap(ftlc)
plt.xlabel('Real')
plt.ylabel('Imaginario')
plt.title('Plano complejo. Polos del sistema en LC')
plt.show(block=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/control/pzmap.py:318: FutureWarning: pole_zero_plot() return value of poles, zeros is deprecated; use pole_zero_map()
#   warnings.warn(

# %%
# Respuesta escalón del sistema en LA y LC
plt.figure(2, figsize=[6, 4])
yout, T = step(ftla, T=25)
yout1, T1 = step(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel('tiempo (s)')
plt.ylabel('$y(t)$')
plt.title('Respuesta escalón sistema en LA y LC')
plt.grid()

# %%
# Respuesta escalón del sistema en LA y LC
plt.figure(3, figsize=[6, 4])
yout, T = impulse(ftla, T=25)
yout1, T1 = impulse(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel('tiempo (s)')
plt.ylabel('$y(t)$')
plt.title('Respuesta impulso sistema en LA y LC')
plt.grid()
plt.show()

# %% [markdown]
# ## SISTEMA CIRCUITO RC

# %%
#definición del sistema RC
num=[1., 0.722, 0.1234]
den=[1., 1.092, 0.1234]
ftla= tf(num, den)
print('Funcion de transferencia en LA de la planta: ')
print(ftla)
ftlc=feedback(ftla,1)
print("Funcion de transferencia en lazo cerrado  de la planta: ")
print(ftlc)
# Out:
# Funcion de transferencia en LA de la planta:
# <TransferFunction>: sys[11]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 + 0.722 s + 0.1234
# ----------------------
# s^2 + 1.092 s + 0.1234
#
# Funcion de transferencia en lazo cerrado  de la planta:
# <TransferFunction>: sys[13]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#  s^2 + 0.722 s + 0.1234
# ------------------------
# 2 s^2 + 1.814 s + 0.2468

# %%
# Grafico de polos y ceros del sistema en lazo cerrado.
plt.figure(1, figsize=[7, 4])
pzmap(ftlc)
plt.xlabel('Real')
plt.ylabel('Imaginario')
plt.title('Plano complejo. Polos del sistema en RC')
plt.show(block=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/control/pzmap.py:318: FutureWarning: pole_zero_plot() return value of poles, zeros is deprecated; use pole_zero_map()
#   warnings.warn(

# %%
# Respuesta escalón del sistema en LA y LC
plt.figure(2, figsize=[6, 4])
yout, T = step(ftla, T=25)
yout1, T1 = step(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel('tiempo (s)')
plt.ylabel('$y(t)$')
plt.title('Respuesta escalón sistema en LA y LC')
plt.grid()

# %%
# Respuesta escalón del sistema en LA y LC
plt.figure(3, figsize=[6, 4])
yout, T = impulse(ftla, T=25)
yout1, T1 = impulse(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel('tiempo (s)')
plt.ylabel('$y(t)$')
plt.title('Respuesta impulso sistema en LA y LC')
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/control/timeresp.py:1975: UserWarning: System has direct feedthrough: ``D != 0``. The infinite impulse at ``t=0`` does not appear in the output.
# Results may be meaningless!
#   warnings.warn("System has direct feedthrough: ``D != 0``. The "

# %% [markdown]
# ## SISTEMA MASA - RESORTE - AMORTIGUADOR

# %%
#definición del sistema masa - resorte - amortiguador
num=[1., 6.75, 0.222]
den=[1., 8.255, 0.222]
ftla= tf(num, den)
print('Funcion de transferencia en LA de la planta: ')
print(ftla)
ftlc=feedback(ftla,1)
print("Funcion de transferencia en lazo cerrado  de la planta: ")
print(ftlc)
# Out:
# Funcion de transferencia en LA de la planta:
# <TransferFunction>: sys[22]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 + 6.75 s + 0.222
# ---------------------
# s^2 + 8.255 s + 0.222
#
# Funcion de transferencia en lazo cerrado  de la planta:
# <TransferFunction>: sys[24]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#  s^2 + 6.75 s + 0.222
# -----------------------
# 2 s^2 + 15.01 s + 0.444

# %%
# Grafico de polos y ceros del sistema en lazo cerrado.
plt.figure(1, figsize=[7, 4])
pzmap(ftlc)
plt.xlabel('Real')
plt.ylabel('Imaginario')
plt.title('Plano complejo. Polos del sistema en LC')
plt.show(block=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/control/pzmap.py:318: FutureWarning: pole_zero_plot() return value of poles, zeros is deprecated; use pole_zero_map()
#   warnings.warn(

# %%
# Respuesta escalón del sistema en LA y LC
plt.figure(2, figsize=[6, 4])
yout, T = step(ftla, T=25)
yout1, T1 = step(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel('tiempo (s)')
plt.ylabel('$y(t)$')
plt.title('Respuesta escalón sistema en LA y LC')
plt.grid()

# %%
# Respuesta escalón del sistema en LA y LC
plt.figure(3, figsize=[6, 4])
yout, T = impulse(ftla, T=25)
yout1, T1 = impulse(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel('tiempo (s)')
plt.ylabel('$y(t)$')
plt.title('Respuesta impulso sistema en LA y LC')
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/control/timeresp.py:1975: UserWarning: System has direct feedthrough: ``D != 0``. The infinite impulse at ``t=0`` does not appear in the output.
# Results may be meaningless!
#   warnings.warn("System has direct feedthrough: ``D != 0``. The "
